# %% [markdown]
# # linear regression using sckitlearn

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

# %%
data=pd.read_csv("..\\data\\Housing.csv")
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# # very important to set up data from before work

# %%
set_data=(np.select(
    [data.isin(["yes","furnished"]) , data.isin(["no","semi-furnished"]), data=="unfurnished"]        # conditions
    , [1,0,-1]                                                                                        # results if condition
    ,default=data                                                                                     # default
))
data.iloc[:,:]=set_data

# %%
x=data.drop("price",axis=1)
y=data[["price"]]

# %% [markdown]
# # creating the linear model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.10)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.6756648138515562

# %%
######################################################################################

# %% [markdown]
# # Creating the polynomial model

# %%
poly=PolynomialFeatures(degree=2,include_bias=False)

# %%
x_x_train=poly.fit_transform(x_train)
x_x_test=poly.fit_transform(x_test)

# %%
model_2 = LinearRegression()

# %%
model_2.fit(x_x_train,y_train)
# Out:
# LinearRegression()

# %%
model_2.score(x_x_test,y_test) , model_2.score(x_x_train,y_train)
# Out:
# (0.6594649436946922, 0.7729945415393896)

# %% [markdown]
# ## system of polynomial regression will not be accurate for this data cus of over fitting
# #### more data should be collected if we wanted to apply poly regression
